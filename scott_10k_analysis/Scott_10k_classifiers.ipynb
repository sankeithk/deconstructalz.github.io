# %% [markdown]
# ### Scott 10K classifiers

# %% [markdown]
# #### See which set of beta coefficients (desikan or destrieux) perform best:
# #### See which model works best for (a) performance and/or (b) SHAP
# #### Use k-fold cross validation: MAKE SURE THAT SCALING TRAIN DATA AND TEST DATA IS SEPARATE TO AVOID LEAKAGE
# #### For best performing model (overall) and best performing tree-based model, check AUC-PR per fold to see if performance distribution is alike

# %%
# %%bash
#
# mkdir -p /rds/general/project/c3nl_scott_students/live/sankeith/scott_10k_analysis/classifiers

# %%
import pandas as pd
import numpy as np
import os
import sklearn
import shap
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.metrics import precision_recall_curve, auc, accuracy_score, f1_score, recall_score, average_precision_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from matplotlib import font_manager


font_path = "/rds/general/user/sk4724/home/arial.ttf"
font_manager.fontManager.addfont(font_path)

plt.rcParams['font.family'] = 'Arial'

df = pd.read_csv('/rds/general/project/c3nl_scott_students/live/sankeith/scott_10k_housekeeping/sbm_w_vbm_scott10k_alliedhealth.csv', low_memory = False)

column_dicts = {
    'desikan_coeffs' : ['desikan_D1', 'desikan_D2', 'desikan_DAT', 'desikan_NET', 'desikan_5HT1A', 'desikan_5HT1B', 'desikan_5HT2A', 'desikan_5HT4', 'desikan_5HT6', 'desikan_5HTT', 'desikan_a4b2', 'desikan_M1', 'desikan_vAChT', 'desikan_NMDA',	'desikan_mGluR5', 'desikan_GABAA/BZ', 'desikan_H3', 'desikan_CB1', 'desikan_MOR'],
    'flipped_desikan_coeffs' : ['flipped_desikan_D1', 'flipped_desikan_D2', 'flipped_desikan_DAT', 'flipped_desikan_NET', 'flipped_desikan_5HT1A', 'flipped_desikan_5HT1B', 'flipped_desikan_5HT2A', 'flipped_desikan_5HT4', 'flipped_desikan_5HT6', 'flipped_desikan_5HTT', 'flipped_desikan_a4b2', 'flipped_desikan_M1', 'flipped_desikan_vAChT', 'flipped_desikan_NMDA',	'flipped_desikan_mGluR5', 'flipped_desikan_GABAA/BZ', 'flipped_desikan_H3', 'flipped_desikan_CB1', 'flipped_desikan_MOR'],
    'destrieux_coeffs' : ['destrieux_D1', 'destrieux_D2', 'destrieux_DAT', 'destrieux_NET', 'destrieux_5HT1A', 'destrieux_5HT1B', 'destrieux_5HT2A', 'destrieux_5HT4', 'destrieux_5HT6', 'destrieux_5HTT', 'destrieux_a4b2', 'destrieux_M1', 'destrieux_vAChT', 'destrieux_NMDA',	'destrieux_mGluR5', 'destrieux_GABAA/BZ', 'destrieux_H3', 'destrieux_CB1', 'destrieux_MOR'],
    'flipped_destrieux_coeffs' : ['flipped_destrieux_D1', 'flipped_destrieux_D2', 'flipped_destrieux_DAT', 'flipped_destrieux_NET', 'flipped_destrieux_5HT1A', 'flipped_destrieux_5HT1B', 'flipped_destrieux_5HT2A', 'flipped_destrieux_5HT4', 'flipped_destrieux_5HT6', 'flipped_destrieux_5HTT', 'flipped_destrieux_a4b2', 'flipped_destrieux_M1', 'flipped_destrieux_vAChT', 'flipped_destrieux_NMDA',	'flipped_destrieux_mGluR5', 'flipped_destrieux_GABAA/BZ', 'flipped_destrieux_H3', 'flipped_destrieux_CB1', 'flipped_destrieux_MOR']
}

df = df[(df['DIAGNOSIS'] == 1) | (df['DIAGNOSIS'] == 3)]

diags = df['DIAGNOSIS']

print(diags.value_counts())

desikan_df = df[['DIAGNOSIS'] + column_dicts['desikan_coeffs']].dropna()

desikan_diags = desikan_df['DIAGNOSIS'].map(lambda x: 0 if x == 1 else 1)

desikan_df = desikan_df.drop(columns = 'DIAGNOSIS')


destrieux_df = df[['DIAGNOSIS'] + column_dicts['destrieux_coeffs']].dropna()

destrieux_diags = destrieux_df['DIAGNOSIS'].map(lambda x: 0 if x == 1 else 1)

destrieux_df = destrieux_df.drop(columns = 'DIAGNOSIS')


flipped_desikan_df = df[['DIAGNOSIS'] + column_dicts['flipped_desikan_coeffs']].dropna()

flipped_desikan_diags = flipped_desikan_df['DIAGNOSIS'].map(lambda x: 0 if x == 1 else 1)

flipped_desikan_df = flipped_desikan_df.drop(columns = 'DIAGNOSIS')


flipped_destrieux_df = df[['DIAGNOSIS'] + column_dicts['flipped_destrieux_coeffs']].dropna()

flipped_destrieux_diags = flipped_destrieux_df['DIAGNOSIS'].map(lambda x: 0 if x == 1 else 1)

flipped_destrieux_df = flipped_destrieux_df.drop(columns = 'DIAGNOSIS')



scaler = StandardScaler()

seed = 42

kf = KFold()

lr = LogisticRegression(random_state = seed, class_weight = 'balanced')

rf = RandomForestClassifier(random_state = seed, class_weight = 'balanced')

svc = SVC(random_state = seed, probability = True, class_weight = 'balanced', kernel = 'rbf') # default kernel is linear which is unfair for non-linearly separable data

knn = KNeighborsClassifier()

gnb = GaussianNB()


for X, y, flag in [(desikan_df, desikan_diags, 'desikan'), (destrieux_df, destrieux_diags, 'destrieux'), (flipped_desikan_df, flipped_desikan_diags, 'flipped_desikan'), (flipped_destrieux_df, flipped_destrieux_diags, 'flipped_destrieux')]:

    xgb_balancer = float(y[y == 0].shape[0])/ float(y[y == 1].shape[0])
    print(xgb_balancer)

    ## Instantiate xgb with the balancer - mitigates class imbalance
    
    xgb = XGBClassifier(random_state = seed, scale_pos_weight = xgb_balancer)


    accuracies_lr = []
    f1_scores_lr = []
    sensitivities_lr = []
    aucprs_lr = []

    accuracies_rf = []
    f1_scores_rf = []
    sensitivities_rf = []
    aucprs_rf = []

    accuracies_svc = []
    f1_scores_svc = []
    sensitivities_svc = []
    aucprs_svc = []

    accuracies_xgb = []
    f1_scores_xgb = []
    sensitivities_xgb = []
    aucprs_xgb = []

    accuracies_knn = []
    f1_scores_knn = []
    sensitivities_knn = []
    aucprs_knn = []

    accuracies_gnb = []
    f1_scores_gnb = []
    sensitivities_gnb = []
    aucprs_gnb = []
    
    list_shap_values = list()
    list_test_sets = list()

    list_shap_values_xgb = list()

    list_X_test_scaled = []

    for i, (train_index, test_index) in enumerate(kf.split(X)):
        print(f"Fold {i}")

        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train,y_test = y.iloc[train_index], y.iloc[test_index]

        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        list_X_test_scaled.append(X_test)
        
        lr.fit(X_train, y_train)
        rf.fit(X_train, y_train)
        svc.fit(X_train, y_train)
        xgb.fit(X_train, y_train)
        knn.fit(X_train, y_train)
        gnb.fit(X_train, y_train)

        
        lr_pred_diags = lr.predict(X_test)
        rf_pred_diags = rf.predict(X_test)
        svc_pred_diags = svc.predict(X_test)
        xgb_pred_diags = xgb.predict(X_test)
        knn_pred_diags = knn.predict(X_test)
        gnb_pred_diags = gnb.predict(X_test)


        lr_pred_probas = lr.predict_proba(X_test)[:,1]
        rf_pred_probas = rf.predict_proba(X_test)[:,1]
        svc_pred_probas = svc.predict_proba(X_test)[:,1]
        xgb_pred_probas = xgb.predict_proba(X_test)[:,1]
        knn_pred_probas = knn.predict_proba(X_test)[:,1]
        gnb_pred_probas = gnb.predict_proba(X_test)[:,1]

        precision_lr, recall_lr, thresholds_lr = precision_recall_curve(y_test, lr_pred_probas)
        precision_rf, recall_rf, thresholds_rf = precision_recall_curve(y_test, rf_pred_probas)
        precision_svc, recall_svc, thresholds_svc = precision_recall_curve(y_test, svc_pred_probas)
        precision_xgb, recall_xgb, thresholds_xgb = precision_recall_curve(y_test, xgb_pred_probas)
        precision_knn, recall_knn, thresholds_knn = precision_recall_curve(y_test, knn_pred_probas)
        precision_gnb, recall_gnb, thresholds_gnb = precision_recall_curve(y_test, gnb_pred_probas)
        
        aucpr_lr = auc(recall_lr, precision_lr)
        aucprs_lr.append(aucpr_lr)
        aucpr_rf = auc(recall_rf, precision_rf)
        aucprs_rf.append(aucpr_rf)
        aucpr_svc = auc(recall_svc, precision_svc)
        aucprs_svc.append(aucpr_svc)
        aucpr_xgb = auc(recall_xgb, precision_xgb)
        aucprs_xgb.append(aucpr_xgb)
        aucpr_knn = auc(recall_knn, precision_knn)
        aucprs_knn.append(aucpr_knn)
        aucpr_gnb = auc(recall_gnb, precision_gnb)
        aucprs_gnb.append(aucpr_gnb)
        
        acc_lr = accuracy_score(y_test, lr_pred_diags)
        accuracies_lr.append(acc_lr)
        acc_rf = accuracy_score(y_test, rf_pred_diags)
        accuracies_rf.append(acc_rf)
        acc_svc = accuracy_score(y_test, svc_pred_diags)
        accuracies_svc.append(acc_svc)
        acc_xgb = accuracy_score(y_test, xgb_pred_diags)
        accuracies_xgb.append(acc_xgb)
        acc_knn = accuracy_score(y_test, knn_pred_diags)
        accuracies_knn.append(acc_knn)
        acc_gnb = accuracy_score(y_test, gnb_pred_diags)
        accuracies_gnb.append(acc_gnb)
        
        f1_lr = f1_score(y_test, lr_pred_diags)
        f1_scores_lr.append(f1_lr)
        f1_rf = f1_score(y_test, rf_pred_diags)
        f1_scores_rf.append(f1_rf)
        f1_svc = f1_score(y_test, svc_pred_diags)
        f1_scores_svc.append(f1_svc)
        f1_xgb = f1_score(y_test, xgb_pred_diags)
        f1_scores_xgb.append(f1_xgb)
        f1_knn = f1_score(y_test, knn_pred_diags)
        f1_scores_knn.append(f1_knn)
        f1_gnb = f1_score(y_test, gnb_pred_diags)
        f1_scores_gnb.append(f1_gnb)
        
        sensitivity_lr = recall_score(y_test, lr_pred_diags)
        sensitivities_lr.append(sensitivity_lr)
        sensitivity_rf = recall_score(y_test, rf_pred_diags)
        sensitivities_rf.append(sensitivity_rf)
        sensitivity_svc = recall_score(y_test, svc_pred_diags)
        sensitivities_svc.append(sensitivity_svc)
        sensitivity_xgb = recall_score(y_test, xgb_pred_diags)
        sensitivities_xgb.append(sensitivity_xgb)
        sensitivity_knn = recall_score(y_test, knn_pred_diags)
        sensitivities_knn.append(sensitivity_knn)
        sensitivity_gnb = recall_score(y_test, gnb_pred_diags)
        sensitivities_gnb.append(sensitivity_gnb)
        
        explainer = shap.TreeExplainer(rf)
        shap_values = explainer.shap_values(X_test)
        list_shap_values.append(shap_values) # A list of shap values
        list_test_sets.append(test_index)# A list of the order of test set indexes

        xgb_explainer = shap.TreeExplainer(xgb)
        xgb_shap_values = xgb_explainer.shap_values(X_test)
        list_shap_values_xgb.append(xgb_shap_values) # A list of shap values
    

    test_set = list_test_sets[0]
    shap_values = np.array(list_shap_values[0])
    shap_values_xgb = np.array(list_shap_values_xgb[0])

    X_scaled_full = np.concatenate(list_X_test_scaled, axis=0)
    for n in range(1,len(list_test_sets)):
        test_set = np.concatenate((test_set,list_test_sets[n]),axis=0)
        shap_values = np.concatenate((shap_values, np.array(list_shap_values[n])),axis = 0)
        shap_values_xgb = np.concatenate((shap_values_xgb, np.array(list_shap_values_xgb[n])),axis = 0)
    #bringing back variable names    
    plt.figure()
    print(shap_values[:,:,1].shape)
    print(shap_values.shape)
    X_reordered = X.iloc[test_set]
    shap.summary_plot(shap_values[:,:,1], X_reordered, show=False)    
    plt.title(f'CV SHAP Importance (RF) - {flag}', y=1.05)
    plt.savefig(f'/rds/general/project/c3nl_scott_students/live/sankeith/scott_10k_analysis/classifiers/rf_shap_beeswarm_{flag}.png',dpi=600)
    plt.show()
    plt.close()

    print('XGB SHAP INCOMING...')
    print(shap_values_xgb.shape)
    shap.summary_plot(shap_values_xgb, X_reordered, show=False)    
    plt.title(f'CV SHAP Importance (XGB) - {flag}', y=1.05)
    plt.savefig(f'/rds/general/project/c3nl_scott_students/live/sankeith/scott_10k_analysis/classifiers/xgb_shap_beeswarm_{flag}.png',dpi=600)
    plt.show()
    plt.close()
    

    
    flag_u = flag.capitalize()

    data = {
        f"{flag_u} LR accuracy": accuracies_lr,
        f"{flag_u} RF accuracy": accuracies_rf,
        f"{flag_u} SVC accuracy": accuracies_svc,
        f"{flag_u} XGB accuracy": accuracies_xgb,
        f"{flag_u} KNN accuracy": accuracies_knn,
        f"{flag_u} GNB accuracy": accuracies_gnb,
        f"{flag_u} LR F1": f1_scores_lr,
        f"{flag_u} RF F1": f1_scores_rf,
        f"{flag_u} SVC F1": f1_scores_svc,
        f"{flag_u} XGB F1": f1_scores_xgb,
        f"{flag_u} KNN F1": f1_scores_knn,
        f"{flag_u} GNB F1": f1_scores_gnb,
        f"{flag_u} LR Sensitivity": sensitivities_lr,
        f"{flag_u} RF Sensitivity": sensitivities_rf,
        f"{flag_u} SVC Sensitivity": sensitivities_svc,
        f"{flag_u} XGB Sensitivity": sensitivities_xgb,
        f"{flag_u} KNN Sensitivity": sensitivities_knn,
        f"{flag_u} GNB Sensitivity": sensitivities_gnb,
        f"{flag_u} LR AUC-PR": aucprs_lr,
        f"{flag_u} RF AUC-PR": aucprs_rf,
        f"{flag_u} SVC AUC-PR": aucprs_svc,
        f"{flag_u} XGB AUC-PR": aucprs_xgb,
        f"{flag_u} KNN AUC-PR": aucprs_knn,
        f"{flag_u} GNB AUC-PR": aucprs_gnb

    }

    print(data)

    df = pd.DataFrame(data)

    print(df)

    df.to_csv(f'/rds/general/project/c3nl_scott_students/live/sankeith/scott_10k_analysis/classifiers/fold_metrics_{flag}.csv', index = False)
# Out:
# DIAGNOSIS
# 1.0    4039
# 3.0    2836
# Name: count, dtype: int64
# 1.4232804232804233
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# (6870, 19)
# (6870, 19, 2)
# XGB SHAP INCOMING...
# (6870, 19)
# {'Desikan LR accuracy': [0.8755458515283843, 0.8646288209606987, 0.8624454148471615, 0.8820960698689956, 0.8384279475982532], 'Desikan RF accuracy': [0.8573508005822417, 0.8413391557496361, 0.8420669577874818, 0.8653566229985444, 0.8289665211062591], 'Desikan SVC accuracy': [0.8777292576419214, 0.8500727802037845, 0.8573508005822417, 0.8704512372634643, 0.8449781659388647], 'Desikan XGB accuracy': [0.8704512372634643, 0.8442503639010189, 0.8384279475982532, 0.8595342066957787, 0.8311499272197962], 'Desikan KNN accuracy': [0.8245997088791849, 0.789665211062591, 0.8027656477438136, 0.8304221251819505, 0.8114992721979621], 'Desikan GNB accuracy': [0.834061135371179, 0.8165938864628821, 0.8245997088791849, 0.8617176128093159, 0.8369723435225619], 'Desikan LR F1': [0.8463611859838275, 0.8590909090909091, 0.8331862312444837, 0.8454198473282443, 0.7823529411764706], 'Desikan RF F1': [0.8218181818181818, 0.8264331210191083, 0.7992599444958371, 0.8191593352883676, 0.7698334965719883], 'Desikan SVC F1': [0.8469945355191257, 0.8420245398773006, 0.8227848101265823, 0.8304761904761905, 0.7901477832512315], 'Desikan XGB F1': [0.838475499092559, 0.8343653250773994, 0.7970749542961609, 0.8170616113744076, 0.7764932562620424], 'Desikan KNN F1': [0.7680461982675649, 0.7540425531914894, 0.7396733909702209, 0.7662988966900702, 0.731048805815161], 'Desikan GNB F1': [0.7949640287769785, 0.797752808988764, 0.7807097361237488, 0.8137254901960784, 0.7837837837837838], 'Desikan LR Sensitivity': [0.8579234972677595, 0.8387573964497042, 0.8368794326241135, 0.8535645472061657, 0.7571157495256167], 'Desikan RF Sensitivity': [0.8233151183970856, 0.7677514792899408, 0.7659574468085106, 0.8073217726396917, 0.74573055028463], 'Desikan SVC Sensitivity': [0.8469945355191257, 0.8121301775147929, 0.8067375886524822, 0.8400770712909441, 0.7609108159392789], 'Desikan XGB Sensitivity': [0.8415300546448088
# 3                      0.859534                      0.842795
# 4                      0.834061                      0.818049
#
#    Flipped_desikan KNN accuracy  Flipped_desikan GNB accuracy  \
# 0                      0.815138                      0.848617
# 1                      0.778020                      0.807132
# 2                      0.824600                      0.822416
# 3                      0.821689                      0.850073
# 4                      0.779476                      0.824600
#
#    Flipped_desikan LR F1  Flipped_desikan RF F1  Flipped_desikan SVC F1  \
# 0               0.838129               0.812030                0.821333
# 1               0.853190               0.807074                0.830131
# 2               0.820870               0.800365                0.810714
# 3               0.805687               0.810811                0.814601
# 4               0.770443               0.762487                0.776031
#
#    Flipped_desikan XGB F1  ...  Flipped_desikan SVC Sensitivity  \
# 0                0.799293  ...                         0.841530
# 1                0.806502  ...                         0.798817
# 2                0.783078  ...                         0.804965
# 3                0.793499  ...                         0.816956
# 4                0.753452  ...                         0.749526
#
#    Flipped_desikan XGB Sensitivity  Flipped_desikan KNN Sensitivity  \
# 0                         0.823315                         0.683060
# 1                         0.770710                         0.650888
# 2                         0.771277                         0.735816
# 3                         0.799615                         0.699422
# 4                         0.724858                         0.626186
#
#    Flipped_desikan GNB Sensitivity  Flipped_desikan LR AUC-PR  \
# 0                         0.768670                   0.917961
# 1                         0.732249                   0.930168
# 2                         0.760638                   0.902071
# 3                         0.747592                   0.904666
# 4                         0.696395                   0.863851
#
#    Flipped_desikan RF AUC-PR  Flipped_desikan SVC AUC-PR  \
# 0                   0.859156                    0.893878
# 1                   0.899022                    0.909399
# 2                   0.832254                    0.880997
# 3                   0.891455                    0.896909
# 4                   0.836570                    0.859728
#
#    Flipped_desikan XGB AUC-PR  Flipped_desikan KNN AUC-PR  \
# 0                    0.884437                    0.826144
# 1                    0.897780                    0.846709
# 2                    0.863454                    0.821295
# 3                    0.881202                    0.824014
# 4                    0.841132                    0.766089
#
#    Flipped_desikan GNB AUC-PR
# 0                    0.879350
# 1                    0.881151
# 2                    0.827708
# 3                    0.866364
# 4                    0.824663
#
# [5 rows x 24 columns]
# 1.4232804232804233
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# (6870, 19)
# (6870, 19, 2)
# XGB SHAP INCOMING...
# (6870, 19)
# {'Flipped_destrieux LR accuracy': [0.8631732168850073, 0.8347889374090247, 0.834061135371179, 0.8529839883551674, 0.8238719068413392], 'Flipped_destrieux RF accuracy': [0.868995633187773, 0.8413391557496361, 0.839155749636099, 0.8653566229985444, 0.834061135371179], 'Flipped_destrieux SVC accuracy': [0.8544395924308588, 0.8398835516739447, 0.846433770014556, 0.851528384279476, 0.8413391557496361], 'Flipped_destrieux XGB accuracy': [0.8435225618631732, 0.8500727802037845, 0.8333333333333334, 0.8260553129548762, 0.8296943231441049], 'Flipped_destrieux KNN accuracy': [0.8304221251819505, 0.8107714701601164, 0.8245997088791849, 0.8231441048034934, 0.8093158660844251], 'Flipped_destrieux GNB accuracy': [0.8558951965065502, 0.8420669577874818, 0.8406113537117904, 0.86608442503639, 0.834061135371179], 'Flipped_destrieux LR F1': [0.8315412186379928, 0.8255188316679477, 0.8013937282229965, 
# 3                        0.823144                        0.866084
# 4                        0.809316                        0.834061
#
#    Flipped_destrieux LR F1  Flipped_destrieux RF F1  Flipped_destrieux SVC F1  \
# 0                 0.831541                 0.829868                  0.817185
# 1                 0.825519                 0.824477                  0.823718
# 2                 0.801394                 0.800000                  0.807306
# 3                 0.809074                 0.812563                  0.800391
# 4                 0.758964                 0.764463                  0.776639
#
#    Flipped_destrieux XGB F1  ...  Flipped_destrieux SVC Sensitivity  \
# 0                  0.805781  ...                           0.814208
# 1                  0.838050  ...                           0.760355
# 2                  0.792760  ...                           0.783688
# 3                  0.772164  ...                           0.788054
# 4                  0.765060  ...                           0.719165
#
#    Flipped_destrieux XGB Sensitivity  Flipped_destrieux KNN Sensitivity  \
# 0                           0.812386                           0.743169
# 1                           0.788462                           0.684911
# 2                           0.776596                           0.748227
# 3                           0.780347                           0.691715
# 4                           0.722960                           0.647059
#
#    Flipped_destrieux GNB Sensitivity  Flipped_destrieux LR AUC-PR  \
# 0                           0.805100                     0.917035
# 1                           0.764793                     0.916249
# 2                           0.790780                     0.887202
# 3                           0.791908                     0.896678
# 4                           0.688805                     0.853781
#
#    Flipped_destrieux RF AUC-PR  Flipped_destrieux SVC AUC-PR  \
# 0                     0.903004                      0.902343
# 1                     0.919782                      0.909185
# 2                     0.893398                      0.889876
# 3                     0.895102                      0.888159
# 4                     0.843803                      0.851814
#
#    Flipped_destrieux XGB AUC-PR  Flipped_destrieux KNN AUC-PR  \
# 0                      0.892004                      0.854286
# 1                      0.919348                      0.889967
# 2                      0.878871                      0.849224
# 3                      0.881263                      0.842861
# 4                      0.852861                      0.807037
#
#    Flipped_destrieux GNB AUC-PR
# 0                      0.894815
# 1                      0.894160
# 2                      0.849394
# 3                      0.885779
# 4                      0.831135
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Get mean performance metrrics for each model for each set of beta coefficients, then count which model won the most categories in each set of beta coefficients

# %%
import pandas as pd
import numpy as np
import os, re

root_path = '/rds/general/project/c3nl_scott_students/live/sankeith/scott_10k_analysis/classifiers/'


for file_name in ['fold_metrics_desikan.csv', 'fold_metrics_destrieux.csv', 'fold_metrics_flipped_desikan.csv', 'fold_metrics_flipped_destrieux.csv']:

    lr_points = 0
    rf_points = 0
    svc_points = 0
    xgb_points = 0
    knn_points = 0
    gnb_points = 0
    
    full_metrics_path = os.path.join(root_path, file_name)
    metrics_df = pd.read_csv(full_metrics_path, low_memory = False)
    metrics_df_cols = metrics_df.columns.tolist()
    accuracy_cols = [col for col in metrics_df_cols if "accuracy" in col.split(' ')]
    f1_cols = [col for col in metrics_df_cols if "F1" in col.split(' ')]
    sensitivity_cols = [col for col in metrics_df_cols if "Sensitivity" in col.split(' ')]
    aucpr_cols = [col for col in metrics_df_cols if "AUC-PR" in col.split(' ')]

    metrics_df_mean = metrics_df.mean()
    mean_acc = metrics_df_mean[accuracy_cols]
    mean_f1 = metrics_df_mean[f1_cols]
    mean_sensitivity = metrics_df_mean[sensitivity_cols]
    mean_aucpr = metrics_df_mean[aucpr_cols]

    for mean_metrics in [mean_acc, mean_f1, mean_sensitivity, mean_aucpr]:
        print(mean_metrics.idxmax(), mean_metrics.max())
        winner_label_parts = mean_metrics.idxmax().split(' ')
        if 'LR' in winner_label_parts:
            lr_points += 1
        elif 'RF' in winner_label_parts:
            rf_points += 1
        elif 'SVC' in winner_label_parts:
            svc_points += 1
        elif 'XGB' in winner_label_parts:
            xgb_points += 1
        elif 'KNN' in winner_label_parts:
            knn_points += 1
        else:
            gnb_points += 1

    winner_name_dict = {
        lr_points : 'Logistic Regression', 
        rf_points : 'Random Forest',
        knn_points : 'K-Nearest Neighbours',
        svc_points : 'Support Vector Classifier',
        gnb_points : 'Gaussian Naive Bayes',
        xgb_points : 'XGBoost'
    }
    winner = max(lr_points, rf_points, svc_points, xgb_points, knn_points, gnb_points)

    print(f"Winner (overall) in {file_name.replace('.csv', '').capitalize()} is {winner_name_dict[winner]}, with {winner} points!")

    if file_name == 'fold_metrics_desikan.csv':
        mean_acc_shap = metrics_df_mean[['Desikan RF accuracy', 'Desikan XGB accuracy']]
        mean_f1_shap = metrics_df_mean[['Desikan RF F1', 'Desikan XGB F1']]
        mean_sensitivity_shap = metrics_df_mean[['Desikan RF Sensitivity', 'Desikan XGB Sensitivity']]
        mean_aucpr_shap = metrics_df_mean[['Desikan RF AUC-PR', 'Desikan XGB AUC-PR']]
    elif file_name == 'fold_metrics_destrieux.csv':
        mean_acc_shap = metrics_df_mean[['Destrieux RF accuracy', 'Destrieux XGB accuracy']]
        mean_f1_shap = metrics_df_mean[['Destrieux RF F1', 'Destrieux XGB F1']]
        mean_sensitivity_shap = metrics_df_mean[['Destrieux RF Sensitivity', 'Destrieux XGB Sensitivity']]
        mean_aucpr_shap = metrics_df_mean[['Destrieux RF AUC-PR', 'Destrieux XGB AUC-PR']]
    elif file_name == 'fold_metrics_flipped_desikan.csv':
        mean_acc_shap = metrics_df_mean[['Flipped_desikan RF accuracy', 'Flipped_desikan XGB accuracy']]
        mean_f1_shap = metrics_df_mean[['Flipped_desikan RF F1', 'Flipped_desikan XGB F1']]
        mean_sensitivity_shap = metrics_df_mean[['Flipped_desikan RF Sensitivity', 'Flipped_desikan XGB Sensitivity']]
        mean_aucpr_shap = metrics_df_mean[['Flipped_desikan RF AUC-PR', 'Flipped_desikan XGB AUC-PR']]
    else:
        mean_acc_shap = metrics_df_mean[['Flipped_destrieux RF accuracy', 'Flipped_destrieux XGB accuracy']]
        mean_f1_shap = metrics_df_mean[['Flipped_destrieux RF F1', 'Flipped_destrieux XGB F1']]
        mean_sensitivity_shap = metrics_df_mean[['Flipped_destrieux RF Sensitivity', 'Flipped_destrieux XGB Sensitivity']]
        mean_aucpr_shap = metrics_df_mean[['Flipped_destrieux RF AUC-PR', 'Flipped_destrieux XGB AUC-PR']]

    rf_points = 0
    xgb_points = 0

    for mean_metrics in [mean_acc_shap, mean_f1_shap, mean_sensitivity_shap, mean_aucpr_shap]:
        print(mean_metrics.idxmax(), mean_metrics.max())
        winner_label_parts = mean_metrics.idxmax().split(' ')
        if 'RF' in winner_label_parts:
            rf_points += 1
        elif 'XGB' in winner_label_parts:
            xgb_points += 1

    winner_name_dict_shap = {
    rf_points : 'Random Forest',
    xgb_points : 'XGBoost'
    }
    winner = max(rf_points, xgb_points)

    print(f"Winner (tree-based model) in {file_name.replace('.csv', '').capitalize()} is {winner_name_dict_shap[winner]}, with {winner} points!")
# Out:
# Desikan LR accuracy 0.8646288209606986
# Desikan LR F1 0.833282222964787
# Desikan LR Sensitivity 0.8288481246146719
# Desikan LR AUC-PR 0.9138416374484495
# Winner (overall) in Fold_metrics_desikan is Logistic Regression, with 4 points!
# Desikan XGB accuracy 0.8487627365356623
# Desikan XGB F1 0.8126941292205139
# Desikan XGB Sensitivity 0.8014132040834516
# Desikan XGB AUC-PR 0.8930571875580732
# Winner (tree-based model) in Fold_metrics_desikan is XGBoost, with 4 points!
# Destrieux SVC accuracy 0.8627365356622999
# Destrieux SVC F1 0.8271174901442073
# Destrieux LR Sensitivity 0.8182184140207889
# Destrieux LR AUC-PR 0.9105645237241256
# Winner (overall) in Fold_metrics_destrieux is Support Vector Classifier, with 2 points!
# Destrieux RF accuracy 0.8540029112081513
# Destrieux RF F1 0.8154271485170032
# Destrieux RF Sensitivity 0.7854767844675704
# Destrieux RF AUC-PR 0.8900020246032352
# Winner (tree-based model) in Fold_metrics_destrieux is Random Forest, with 4 points!
# Flipped_desikan LR accuracy 0.8522561863173218
# Flipped_desikan LR F1 0.8176638938247851
# Flipped_desikan LR Sensitivity 0.8135038658160105
# Flipped_desikan LR AUC-PR 0.9037435225395102
# Winner (overall) in Fold_metrics_flipped_desikan is Logistic Regression, with 4 points!
# Flipped_desikan RF accuracy 0.8426491994177583
# Flipped_desikan RF F1 0.7985533459388219
# Flipped_desikan XGB Sensitivity 0.7779548203736262
# Flipped_desikan XGB AUC-PR 0.8736009072776373
# Winner (tree-based model) in Fold_metrics_flipped_desikan is XGBoost, with 2 points!
# Flipped_destrieux RF accuracy 0.8497816593886464
# Flipped_destrieux RF F1 0.8062740917081612
# Flipped_destrieux LR Sensitivity 0.8005555083806828
# Flipped_destrieux LR AUC-PR 0.8941888653352489
# Winner (overall) in Fold_metrics_flipped_destrieux is Random Forest, with 2 points!
# Flipped_destrieux RF accuracy 0.8497816593886464
# Flipped_destrieux RF F1 0.8062740917081612
# Flipped_destrieux XGB Sensitivity 0.7761500824805492
# Flipped_destrieux RF AUC-PR 0.8910179541742353
# Winner (tree-based model) in Fold_metrics_flipped_destrieux is Random Forest, with 3 points!

# %% [markdown]
# #### Which set of beta coefficients works best in a classifier?

# %%
import pandas as pd
import numpy as np
import os
import re

root_path = '/rds/general/project/c3nl_scott_students/live/sankeith/scott_10k_analysis/classifiers/'

desikan_df = pd.read_csv(os.path.join(root_path, 'fold_metrics_desikan.csv'), low_memory = False)
destrieux_df = pd.read_csv(os.path.join(root_path, 'fold_metrics_destrieux.csv'), low_memory = False)
flipped_desikan_df = pd.read_csv(os.path.join(root_path, 'fold_metrics_flipped_desikan.csv'), low_memory = False)
flipped_destrieux_df = pd.read_csv(os.path.join(root_path, 'fold_metrics_flipped_destrieux.csv'), low_memory = False)

combined_df = desikan_df.join(destrieux_df)
combined_df = combined_df.join(flipped_desikan_df)
combined_df = combined_df.join(flipped_destrieux_df)


print(combined_df)

lr_accuracies = combined_df[['Desikan LR accuracy', 'Destrieux SVC accuracy', 'Flipped_desikan LR accuracy', 'Flipped_destrieux RF accuracy']].mean()
lr_f1s = combined_df[['Desikan LR F1', 'Destrieux SVC F1', 'Flipped_desikan LR F1', 'Flipped_destrieux RF F1']].mean()
lr_sensitvities = combined_df[['Desikan LR Sensitivity', 'Destrieux SVC Sensitivity', 'Flipped_desikan LR Sensitivity', 'Flipped_destrieux RF Sensitivity']].mean()
lr_aucprs = combined_df[['Desikan LR AUC-PR', 'Destrieux SVC AUC-PR', 'Flipped_desikan LR AUC-PR', 'Flipped_destrieux RF AUC-PR']].mean()

desikan_points = 0
destrieux_points = 0
flipped_desikan_points = 0
flipped_destrieux_points = 0

for n in [lr_accuracies, lr_f1s, lr_sensitvities, lr_aucprs]:
    print(n.idxmax(), n.max())
    if 'Desikan' in n.idxmax().split(' '):
        desikan_points += 1
    elif 'Destrieux' in n.idxmax().split(' '):
        destrieux_points += 1
    elif 'Flipped_desikan' in n.idxmax().split(' '):
        flipped_desikan_points += 1
    else:
        flipped_destrieux_points += 1
        

winner_name_dict_atlas = {
    desikan_points : 'Desikan',
    destrieux_points: 'Destrieux',
    flipped_desikan_points: 'Flipped Desikan',
    flipped_destrieux_points: 'Flipped Destrieux'
}

winner = max(desikan_points, destrieux_points)

print(f"Winner is {winner_name_dict_atlas[winner]}, with {winner} points!")
# Out:
#    Desikan LR accuracy  Desikan RF accuracy  Desikan SVC accuracy  \
# 0             0.875546             0.857351              0.877729
# 1             0.864629             0.841339              0.850073
# 2             0.862445             0.842067              0.857351
# 3             0.882096             0.865357              0.870451
# 4             0.838428             0.828967              0.844978
#
#    Desikan XGB accuracy  Desikan KNN accuracy  Desikan GNB accuracy  \
# 0              0.870451              0.824600              0.834061
# 1              0.844250              0.789665              0.816594
# 2              0.838428              0.802766              0.824600
# 3              0.859534              0.830422              0.861718
# 4              0.831150              0.811499              0.836972
#
#    Desikan LR F1  Desikan RF F1  Desikan SVC F1  Desikan XGB F1  ...  \
# 0       0.846361       0.821818        0.846995        0.838475  ...
# 1       0.859091       0.826433        0.842025        0.834365  ...
# 2       0.833186       0.799260        0.822785        0.797075  ...
# 3       0.845420       0.819159        0.830476        0.817062  ...
# 4       0.782353       0.769833        0.790148        0.776493  ...
#
#    Flipped_destrieux SVC Sensitivity  Flipped_destrieux XGB Sensitivity  \
# 0                           0.814208                           0.812386
# 1                           0.760355                           0.788462
# 2                           0.783688                           0.776596
# 3                           0.788054                           0.780347
# 4                           0.719165                           0.722960
#
#    Flipped_destrieux KNN Sensitivity  Flipped_destrieux GNB Sensitivity  \
# 0                           0.743169                           0.805100
# 1                           0.684911                           0.764793
# 2                           0.748227                           0.790780
# 3                           0.691715                           0.791908
# 4                           0.647059                           0.688805
#
#    Flipped_destrieux LR AUC-PR  Flipped_destrieux RF AUC-PR  \
# 0                     0.917035                     0.903004
# 1                     0.916249                     0.919782
# 2                     0.887202                     0.893398
# 3                     0.896678                     0.895102
# 4                     0.853781                     0.843803
#
#    Flipped_destrieux SVC AUC-PR  Flipped_destrieux XGB AUC-PR  \
# 0                      0.902343                      0.892004
# 1                      0.909185                      0.919348
# 2                      0.889876                      0.878871
# 3                      0.888159                      0.881263
# 4                      0.851814                      0.852861
#
#    Flipped_destrieux KNN AUC-PR  Flipped_destrieux GNB AUC-PR
# 0                      0.854286                      0.894815
# 1                      0.889967                      0.894160
# 2                      0.849224                      0.849394
# 3                      0.842861                      0.885779
# 4                      0.807037                      0.831135
#
# [5 rows x 96 columns]
# Desikan LR accuracy 0.8646288209606986
# Desikan LR F1 0.833282222964787
# Desikan LR Sensitivity 0.8288481246146719
# Desikan LR AUC-PR 0.9138416374484495
# Winner is Desikan, with 4 points!

# %% [markdown]
# #### Desikan beta coefficients vs Destrieux beta coefficients - these beta coefficients are most biologically plausible

# %%
import pandas as pd
import numpy as np
import os
import re

root_path = '/rds/general/project/c3nl_scott_students/live/sankeith/scott_10k_analysis/classifiers/'

desikan_df = pd.read_csv(os.path.join(root_path, 'fold_metrics_desikan.csv'), low_memory = False)
destrieux_df = pd.read_csv(os.path.join(root_path, 'fold_metrics_destrieux.csv'), low_memory = False)
combined_df = desikan_df.join(destrieux_df)

print(combined_df)

lr_accuracies = combined_df[['Desikan LR accuracy', 'Destrieux SVC accuracy']].mean()
lr_f1s = combined_df[['Desikan LR F1', 'Destrieux SVC F1']].mean()
lr_sensitvities = combined_df[['Desikan LR Sensitivity', 'Destrieux SVC Sensitivity']].mean()
lr_aucprs = combined_df[['Desikan LR AUC-PR', 'Destrieux SVC AUC-PR']].mean()

desikan_points = 0
destrieux_points = 0

for n in [lr_accuracies, lr_f1s, lr_sensitvities, lr_aucprs]:
    print(n.idxmax(), n.max())
    if 'Desikan' in n.idxmax().split(' '):
        desikan_points += 1
    if 'Destrieux' in n.idxmax().split(' '):
        destrieux_points += 1

winner_name_dict_atlas = {
    desikan_points : 'Desikan',
    destrieux_points: 'Destrieux'
}

winner = max(desikan_points, destrieux_points)

print(f"Winner is {winner_name_dict_atlas[winner]}, with {winner} points!")
# Out:
#    Desikan LR accuracy  Desikan RF accuracy  Desikan SVC accuracy  \
# 0             0.875546             0.857351              0.877729
# 1             0.864629             0.841339              0.850073
# 2             0.862445             0.842067              0.857351
# 3             0.882096             0.865357              0.870451
# 4             0.838428             0.828967              0.844978
#
#    Desikan XGB accuracy  Desikan KNN accuracy  Desikan GNB accuracy  \
# 0              0.870451              0.824600              0.834061
# 1              0.844250              0.789665              0.816594
# 2              0.838428              0.802766              0.824600
# 3              0.859534              0.830422              0.861718
# 4              0.831150              0.811499              0.836972
#
#    Desikan LR F1  Desikan RF F1  Desikan SVC F1  Desikan XGB F1  ...  \
# 0       0.846361       0.821818        0.846995        0.838475  ...
# 1       0.859091       0.826433        0.842025        0.834365  ...
# 2       0.833186       0.799260        0.822785        0.797075  ...
# 3       0.845420       0.819159        0.830476        0.817062  ...
# 4       0.782353       0.769833        0.790148        0.776493  ...
#
#    Destrieux SVC Sensitivity  Destrieux XGB Sensitivity  \
# 0                   0.837887                   0.817851
# 1                   0.766272                   0.773669
# 2                   0.819149                   0.783688
# 3                   0.818882                   0.789981
# 4                   0.755218                   0.760911
#
#    Destrieux KNN Sensitivity  Destrieux GNB Sensitivity  Destrieux LR AUC-PR  \
# 0                   0.781421                   0.834244             0.921363
# 1                   0.667160                   0.766272             0.935521
# 2                   0.719858                   0.758865             0.913788
# 3                   0.689788                   0.820809             0.914768
# 4                   0.637571                   0.759013             0.867382
#
#    Destrieux RF AUC-PR  Destrieux SVC AUC-PR  Destrieux XGB AUC-PR  \
# 0             0.895846              0.922191              0.902428
# 1             0.916210              0.923783              0.915916
# 2             0.891515              0.903610              0.871025
# 3             0.893088              0.912445              0.888463
# 4             0.853352              0.851637              0.855337
#
#    Destrieux KNN AUC-PR  Destrieux GNB AUC-PR
# 0              0.872532              0.893673
# 1              0.875029              0.908325
# 2              0.835044              0.868536
# 3              0.843519              0.893947
# 4              0.789785              0.856324
#
# [5 rows x 48 columns]
# Desikan LR accuracy 0.8646288209606986
# Desikan LR F1 0.833282222964787
# Desikan LR Sensitivity 0.8288481246146719
# Desikan LR AUC-PR 0.9138416374484495
# Winner is Desikan, with 4 points!

# %%
#### Are the performance differences between the RF and XGB models significant? Paired t-test used because low sample size (n = 5)

# %%
import pandas as pd
import numpy as np
import os
import re
import scipy
from scipy.stats import wilcoxon, ttest_rel, levene, kstest

root_path = 'C:/Users/User/Downloads/deconstructalz.github.io/scott_10k_analysis/classifiers/'

desikan_df = pd.read_csv(os.path.join(root_path, 'fold_metrics_desikan.csv'), low_memory = False)
destrieux_df = pd.read_csv(os.path.join(root_path, 'fold_metrics_destrieux.csv'), low_memory = False)
combined_df = desikan_df.join(destrieux_df)

accuracies = combined_df[['Desikan LR accuracy', 'Desikan XGB accuracy']]
f1s = combined_df[['Desikan LR F1', 'Desikan XGB F1']]
sensitivities = combined_df[['Desikan LR Sensitivity', 'Desikan XGB Sensitivity']]
aucprs = combined_df[['Desikan LR AUC-PR', 'Desikan XGB AUC-PR']]

thresh = len([accuracies, f1s, sensitivities, aucprs])

for n in [accuracies, f1s, sensitivities, aucprs]:
    print(n)
    print(n.values[:,0], n.values[:,1])
    _, p_levene = levene(n.values[:,0], n.values[:,1])
    equal_var = p_levene > 0.05

    # 2. Kolmogorov-Smirnov Test for Normality (standardized)
    is_normal = True
    for g in [n.values[:,0], n.values[:,1]]:
        standardised_group = (g - g.mean()) / g.std()
        _, p_ks = kstest(standardised_group, 'norm')
        if p_ks < 0.05:
            is_normal = False
            break

    # 3. Pairwise test
    if is_normal and equal_var:
        test_name = "Paired t-test"
        result = ttest_rel(n.values[:,0], n.values[:,1])
    elif is_normal and not equal_var:
        test_name = "Paired t-test"
        result = ttest_rel(n.values[:,0], n.values[:,1])
    else:
        test_name = "Wilcoxon signed-rank test"
        result = wilcoxon(n.values[:,0], n.values[:,1])

    print(result, test_name, is_normal, equal_var)
    print(f'Raw p-value = {result.pvalue}. Adjusted by n = 4: {float(result.pvalue * thresh)}')
    print(bool(float(result.pvalue) < 0.05))# Prints adjusted p value. Threshold is 4 - for each set of metrics
    print(bool(float(result.pvalue * thresh) < 0.05))# Prints adjusted p value. Threshold is 4 - for each set of metrics
    print(' ')

    ## Focus on the AUC-PR statistic, since that is arguably the most holistic
# Out:
#    Desikan LR accuracy  Desikan XGB accuracy
# 0             0.875546              0.870451
# 1             0.864629              0.844250
# 2             0.862445              0.838428
# 3             0.882096              0.859534
# 4             0.838428              0.831150
# [0.87554585 0.86462882 0.86244541 0.88209607 0.83842795] [0.87045124 0.84425036 0.83842795 0.85953421 0.83114993]
# TtestResult(statistic=np.float64(3.9577531696172086), pvalue=np.float64(0.016709059917068222), df=np.int64(4)) Paired t-test True True
# Raw p-value = 0.016709059917068222. Adjusted by n = 4: 0.06683623966827289
# True
# False
#
#    Desikan LR F1  Desikan XGB F1
# 0       0.846361        0.838475
# 1       0.859091        0.834365
# 2       0.833186        0.797075
# 3       0.845420        0.817062
# 4       0.782353        0.776493
# [0.84636119 0.85909091 0.83318623 0.84541985 0.78235294] [0.8384755  0.83436533 0.79707495 0.81706161 0.77649326]
# TtestResult(statistic=np.float64(3.4881541031934424), pvalue=np.float64(0.02516495802550683), df=np.int64(4)) Paired t-test True True
# Raw p-value = 0.02516495802550683. Adjusted by n = 4: 0.10065983210202732
# True
# False
#
#    Desikan LR Sensitivity  Desikan XGB Sensitivity
# 0                0.857923                 0.841530
# 1                0.838757                 0.797337
# 2                0.836879                 0.773050
# 3                0.853565                 0.830443
# 4                0.757116                 0.764706
# [0.8579235  0.8387574  0.83687943 0.85356455 0.75711575] [0.84153005 0.79733728 0.77304965 0.83044316 0.76470588]
# TtestResult(statistic=np.float64(2.2832931574032123), pvalue=np.float64(0.08447919928332066), df=np.int64(4)) Paired t-test True True
# Raw p-value = 0.08447919928332066. Adjusted by n = 4: 0.33791679713328265
# False
# False
#
#    Desikan LR AUC-PR  Desikan XGB AUC-PR
# 0           0.926181            0.898113
# 1           0.939615            0.913038
# 2           0.919248            0.887930
# 3           0.915560            0.907020
# 4           0.868605            0.859185
# [0.92618085 0.93961472 0.9192479  0.91555979 0.86860492] [0.89811273 0.91303761 0.88793048 0.90702047 0.85918464]
# TtestResult(statistic=np.float64(4.257544013303221), pvalue=np.float64(0.013079168383832787), df=np.int64(4)) Paired t-test True True
# Raw p-value = 0.013079168383832787. Adjusted by n = 4: 0.05231667353533115
# True
# False
